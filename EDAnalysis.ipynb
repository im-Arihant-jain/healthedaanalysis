# %%
print("akjf")
# Out:
# akjf

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
price = [ 1,2,3,4,5]
year = [2000,2001,2002,2003,2005]
plt.plot(year,price)

# %%
batsman = pd.read_csv('sharma-kohli.csv')

# %%
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
pd.plot(batsman['index'],batsman['V Kohli'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.plot(batsman['index'],batsman['V Kohli'])
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
plt.plot(batsman['index'],batsman['RG Sharma'],color='blue'), 
plt.plot(batsman['index'],batsman['V Kohli'],color='green')

# %%
print("ja")
# Out:
# ja

# %%
;rint (ajfk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 rint("(ajfk)")
#
# NameError: name 'rint' is not defined

# %%
plt.scatter(batsman['RG Sharma'],batsman['V Kohli'])

# %%
# bar plot --> bivariate numerical vs categorical
import matplotlib.pyplot as plt
colors = [10,20,30 ,5,20]
children = ['red','blue','green','yellow','pink']
plt.bar(children,colors)
# Out:
# <BarContainer object of 5 artists>
